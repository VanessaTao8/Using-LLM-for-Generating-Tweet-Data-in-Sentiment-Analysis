# %%
from openai import OpenAI
import pandas as pd
client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key = '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' ,
)
model_name = "gpt-3.5-turbo-1106"

# read csv file
csv_path = 'dreaddit-train.csv' 
data = pd.read_csv(csv_path)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 11
#       9 # read csv file
#      10 csv_path = 'dreaddit-train.csv'
# ---> 11 data = pd.read_csv(csv_path)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# 1st
# create a system

user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[:99].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})

# %%
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)

# %%
#generated_content1 = response.choices[0].message.content[63:-31]
generated_content1 = response.choices[0].message.content

# %%
# second
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[:99].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)

# %%
generated_content2 = response.choices[0].message.content

# %%
# third
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[:99].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content3 = response.choices[0].message.content

# %%
# forth
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[:99].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content4 = response.choices[0].message.content

# %%
# fifth
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[:99].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content5 = response.choices[0].message.content

# %%
# sixth
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[:99].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content6 = response.choices[0].message.content

# %%
# seventh
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[:99].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content7 = response.choices[0].message.content

# %%
# eightth
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[:99].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content8 = response.choices[0].message.content

# %%
# nineth
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[100:199].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content9 = response.choices[0].message.content

# %%
# tenth
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[100:199].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content10 = response.choices[0].message.content

# %%
# eleventh
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[100:199].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content11 = response.choices[0].message.content

# %%
# 12th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[100:199].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content12 = response.choices[0].message.content

# %%
# 13th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[100:199].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content13 = response.choices[0].message.content

# %%
# 14th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[100:199].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content14 = response.choices[0].message.content

# %%
# 15th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[100:199].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content15 = response.choices[0].message.content

# %%
# 16th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[100:199].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content16 = response.choices[0].message.content

# %%
# 17th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[200:299].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content17 = response.choices[0].message.content

# %%
# 18th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[200:299].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content18 = response.choices[0].message.content

# %%
# 19th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[200:299].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content19 = response.choices[0].message.content

# %%
# 20th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[200:299].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content20 = response.choices[0].message.content

# %%
# 21th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[200:299].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content21 = response.choices[0].message.content

# %%
# 22th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[200:299].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content22 = response.choices[0].message.content

# %%
# 23th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[200:299].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content23 = response.choices[0].message.content

# %%
# 24th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[200:299].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content24 = response.choices[0].message.content

# %%
# 25th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[300:399].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content25 = response.choices[0].message.content

# %%
# 26th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[300:399].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content26 = response.choices[0].message.content

# %%
# 27th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[300:399].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content27 = response.choices[0].message.content

# %%
# 28th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[300:399].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content28 = response.choices[0].message.content

# %%
# 29th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[300:399].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content29 = response.choices[0].message.content

# %%
# 30th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[300:399].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content30 = response.choices[0].message.content

# %%
# 31th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[300:399].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content31 = response.choices[0].message.content

# %%
# 32th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[300:399].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content32 = response.choices[0].message.content

# %%
# 33th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[400:499].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content33 = response.choices[0].message.content

# %%
# 34th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[400:499].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content34 = response.choices[0].message.content

# %%
# 35th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[400:499].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content35 = response.choices[0].message.content

# %%
# 36th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[400:499].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content36 = response.choices[0].message.content

# %%
# 37th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[400:499].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content37 = response.choices[0].message.content

# %%
# 38th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[400:499].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content38 = response.choices[0].message.content

# %%
# 39th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[400:499].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content39 = response.choices[0].message.content

# %%
# 40th
user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help the user to generate a dataset for stress analysis in social media. Generate 100 rows of new data each time."}]
message = 'Please generate more data exactly in this format: \n{text:"{text}",stress:"{stress}"}, where {text} is the content of the post in Reddit with at most 5 sentences, {stress} is a binary stress label, 0 means non-stress and 1 means stress.\n The following are some examples.\n'

# integragate original data 
for index, row in data[400:499].iterrows():
    m = f'text:"{row["text"]}",stress:"{row["label"]}"\n' 
    message += m

user_messages.append({"role":"user", "content":message})
response = client.chat.completions.create(
model = model_name,
messages = user_messages,
temperature = 1,
max_tokens = 2048,
top_p = 1,
frequency_penalty = 0,
presence_penalty = 0,
n = 2)
generated_content40 = response.choices[0].message.content

# %%
generated_content40
generated_content = generated_content40

# %%
import csv

# %%
generated_content40[2:-1][0][3:]
rows = generated_content.split('\n')[2:-1]
row = rows[1][4:-1].split('},')
new_rows = rows[1].split(': "')
print(new_rows[0][13:-6])
print(new_rows[1].split(' sentiment:')[0][:-2])
print(new_rows[2][:-2])
# Out:
#  going to try to break this down quickly to make sense of it and if not, perhaps someone can give me a line on how to examine this. I think, 'I can't believe how many of the things they tell us we don't have over here or the sort that we don't have at all', and 'it feels like the only those states that are known for being the highest trouble in the country have even known what the standards are (like my state has commercial grade flour, that's should be something from home').",stres
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 6
#       4 new_rows = rows[1].split(': "')
#       5 print(new_rows[0][13:-6])
# ----> 6 print(new_rows[1].split(' sentiment:')[0][:-2])
#       7 print(new_rows[2][:-2])
#
# IndexError: list index out of range

# %%
csv_file_path = 'simpleprompt.csv'

# %%
generated_content1
# Out:
# 'Here are 100 new rows of data in the requested format:\n\n{text:"I recently opened up to my family and told them about my anxiety and depression, and they were super supportive. They helped me find a therapist and encouraged me to start taking care of myself. I\'m so grateful for their understanding and love. It has been a tough journey, but I finally feel like I\'m on the right path to healing and taking control of my mental health.",stress:"0"}\n{text:"My best friend is getting married next weekend, and I\'m so excited to celebrate with her. It\'s been a stressful time leading up to the big day, but seeing her so happy makes it all worth it. I\'m honored to be a part of her special day and can\'t wait to witness her marry the love of her life.",stress:"0"}\n{text:"I recently lost my job due to the company downsizing, and it\'s been a challenging time for me. I\'m trying to stay positive and motivated in my job search, but it\'s tough not knowing what the future holds. I\'m gratefu
# ...

# %%
import re
with open(csv_file_path, 'w', newline = '') as csvfile:
    pattern = r'{text:"(.*?)",stress:"(\d)"\}'
    matches1 = re.findall(pattern, generated_content1)
    writer = csv.writer(csvfile)
    for match in matches1:
        writer.writerow(match)
        
    matches2 = re.findall(pattern, generated_content2)
    writer = csv.writer(csvfile)
    for match in matches2:
        writer.writerow(match)
        
    matches3 = re.findall(pattern, generated_content3)
    writer = csv.writer(csvfile)
    for match in matches3:

        writer.writerow(match)
    
    matches4 = re.findall(pattern, generated_content4)
    writer = csv.writer(csvfile)
    for match in matches4:
       
        writer.writerow(match)
    
    matches5 = re.findall(pattern, generated_content5)
    writer = csv.writer(csvfile)
    for match in matches5:
        
        writer.writerow(match)
    
    matches6 = re.findall(pattern, generated_content6)
    writer = csv.writer(csvfile)
    for match in matches6:
        
        writer.writerow(match)
     
    matches7 = re.findall(pattern, generated_content7)
    writer = csv.writer(csvfile)
    for match in matches7:
       
        writer.writerow(match)
    
    matches8 = re.findall(pattern, generated_content8)
    writer = csv.writer(csvfile)
    for match in matches8:
       
        writer.writerow(match)
    
    matches9 = re.findall(pattern, generated_content9)
    writer = csv.writer(csvfile)
    for match in matches9:
        
        writer.writerow(match)
    
    matches10 = re.findall(pattern, generated_content10)
    writer = csv.writer(csvfile)
    for match in matches10:
        
        writer.writerow(match)
    
    matches11 = re.findall(pattern, generated_content1)
    writer = csv.writer(csvfile)
    for match in matches11:
        
        writer.writerow(match)
        
    matches12 = re.findall(pattern, generated_content12)
    writer = csv.writer(csvfile)
    for match in matches12:
      
        writer.writerow(match)
        
    matches13 = re.findall(pattern, generated_content13)
    writer = csv.writer(csvfile)
    for match in matches13:
       
        writer.writerow(match)
    
    matches14 = re.findall(pattern, generated_content14)
    writer = csv.writer(csvfile)
    for match in matches14:
      
        writer.writerow(match)
    
    matches15 = re.findall(pattern, generated_content15)
    writer = csv.writer(csvfile)
    for match in matches15:
       
        writer.writerow(match)
    
    matches16 = re.findall(pattern, generated_content16)
    writer = csv.writer(csvfile)
    for match in matches16:
       
        writer.writerow(match)
     
    matches17 = re.findall(pattern, generated_content17)
    writer = csv.writer(csvfile)
    for match in matches17:
     
        writer.writerow(match)
    
    matches18 = re.findall(pattern, generated_content18)
    writer = csv.writer(csvfile)
    for match in matches18:
        
        writer.writerow(match)
    
    matches19 = re.findall(pattern, generated_content19)
    writer = csv.writer(csvfile)
    for match in matches19:
        
        writer.writerow(match)
    
    matches20 = re.findall(pattern, generated_content20)
    writer = csv.writer(csvfile)
    for match in matches20:
     
        writer.writerow(match)  
    
    matches21 = re.findall(pattern, generated_content21)
    writer = csv.writer(csvfile)
    for match in matches21:
        
        writer.writerow(match)
        
    matches22 = re.findall(pattern, generated_content22)
    writer = csv.writer(csvfile)
    for match in matches22:
      
        writer.writerow(match)
        
    matches23 = re.findall(pattern, generated_content23)
    writer = csv.writer(csvfile)
    for match in matches23:
        writer.writerow(match)
    
    matches24 = re.findall(pattern, generated_content24)
    writer = csv.writer(csvfile)
    for match in matches24:
        writer.writerow(match)
    
    matches25 = re.findall(pattern, generated_content25)
    writer = csv.writer(csvfile)
    for match in matches25:
        writer.writerow(match)
    
    matches26 = re.findall(pattern, generated_content26)
    writer = csv.writer(csvfile)
    for match in matches26:
        writer.writerow(match)
     
    matches27 = re.findall(pattern, generated_content27)
    writer = csv.writer(csvfile)
    for match in matches27:
        writer.writerow(match)
    
    matches28 = re.findall(pattern, generated_content28)
    writer = csv.writer(csvfile)
    for match in matches28:
        writer.writerow(match)
    
    matches29 = re.findall(pattern, generated_content29)
    writer = csv.writer(csvfile)
    for match in matches29:
        writer.writerow(match)
    
    matches30 = re.findall(pattern, generated_content30)
    writer = csv.writer(csvfile)
    for match in matches30:
        writer.writerow(match)
    
    matches31 = re.findall(pattern, generated_content31)
    writer = csv.writer(csvfile)
    for match in matches31:
        writer.writerow(match)
        
    matches32 = re.findall(pattern, generated_content32)
    writer = csv.writer(csvfile)
    for match in matches32:
        writer.writerow(match)
        
    matches33 = re.findall(pattern, generated_content33)
    writer = csv.writer(csvfile)
    for match in matches33:
        writer.writerow(match)
    
    matches34 = re.findall(pattern, generated_content34)
    writer = csv.writer(csvfile)
    for match in matches34:
        writer.writerow(match)
    
    matches35 = re.findall(pattern, generated_content35)
    writer = csv.writer(csvfile)
    for match in matches35:
        writer.writerow(match)
    
    matches36 = re.findall(pattern, generated_content36)
    writer = csv.writer(csvfile)
    for match in matches36:
        writer.writerow(match)
     
    matches37 = re.findall(pattern, generated_content37)
    writer = csv.writer(csvfile)
    for match in matches37:
        writer.writerow(match)
    
    matches38 = re.findall(pattern, generated_content38)
    writer = csv.writer(csvfile)
    for match in matches38:
        writer.writerow(match)
    
    matches39 = re.findall(pattern, generated_content39)
    writer = csv.writer(csvfile)
    for match in matches39:
        writer.writerow(match)
    
    matches40 = re.findall(pattern, generated_content40)
    writer = csv.writer(csvfile)
    for match in matches40:
        writer.writerow(match)

# %%
pattern = r'\{post_id: (\w+). text: "([^"]+)". sentiment: ([^,]+). label: (\w+)\}'
matches40 = re.findall(pattern, generated_content40)
writer = csv.writer(csvfile)
for match in matches1:
    post_id, text, sentiment, label = match
    print(match)

# %%
with open(csv_file_path, 'w', newline = '') as csvfile:
    for i in range(100):
        user_messages = [{"role":"system", "content":"You are a helpful assistent. Please help user to generate dataset for him, Please generate 100 new data"}]
        message = "Please generate more data look like this: \n{post_id: {post_id}. text: {text}. sentiment:{sentiment}. label:{label}}. Here's the requirement: 1. {text} should be the contents of the tweet. 2. {label} should be the subrredit category. 3.{sentiment} shou;d be the sentiment level of the content"

        # integragate original data
        for index, row in data[i*10:i*10+10].iterrows():
            m = f" {row['post_id']}\t{row['text']}\t{row['sentiment']}\t{row['subreddit']}\n" 
            message += m

        user_messages.append({"role":"user", "content":message})
        response = client.chat.completions.create(
        model = model_name,
        messages = user_messages,
        temperature = 1,
        max_tokens = 2048,
        top_p = 1,
        frequency_penalty = 0,
        presence_penalty = 0,
        n = 2)
        generated_content1 = response.choices[0].message.content
    
        pattern = r'\{post_id: (\w+). text: "([^"]+)". sentiment: ([^,]+). label: (\w+)\}'
        matches1 = re.findall(pattern, generated_content1)
        writer = csv.writer(csvfile)
        for match in matches1:
            post_id, text, sentiment, label = match
            writer.writerow(match)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 12
#       9     message += m
#      11 user_messages.append({"role":"user", "content":message})
# ---> 12 response = client.chat.completions.create(
#      13 model = model_name,
#      14 messages = user_messages,
#      15 temperature = 1,
#      16 max_tokens = 2048,
#      17 top_p = 1,
#      18 frequency_penalty = 0,
#      19 presence_penalty = 0,
#      20 n = 2)
#      21 generated_content1 = response.choices[0].message.content
#      23 pattern = r'\{post_id: (\w+). text: "([^"]+)". sentiment: ([^,]+). label: (\w+)\}'
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_utils/_utils.py:299, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297             msg = f"Missing required argument: {quote(missing[0])}"
#     298     raise TypeError(msg)
# ...

# %%
generated_content1

# %%
with open(csv_file_path, 'w', newline = '') as csvfile:
    pattern = r'{text:"(.*?)",stress:"(\d)"\}'
    matches1 = re.findall(pattern, generated_content1)
    writer = csv.writer(csvfile)
    for match in matches1:
        print(match)
        writer.writerow(match)
# Out:
# ("I recently opened up to my family and told them about my anxiety and depression, and they were super supportive. They helped me find a therapist and encouraged me to start taking care of myself. I'm so grateful for their understanding and love. It has been a tough journey, but I finally feel like I'm on the right path to healing and taking control of my mental health.", '0')
# ("My best friend is getting married next weekend, and I'm so excited to celebrate with her. It's been a stressful time leading up to the big day, but seeing her so happy makes it all worth it. I'm honored to be a part of her special day and can't wait to witness her marry the love of her life.", '0')
# ...
